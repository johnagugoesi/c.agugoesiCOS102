# %%
import tkinter as tk
from tkinter import messagebox as msgbox

# Handling button click event
def button_click():
    # print("button clicked")

    # Show an information message box
    msgbox.showinfo("Info","Welcome to COS102 GUI Application")

    # Ask for user confirmation 
    result = msgbox.askyesno("Confirmation", "Do you want to continue?")

# Create the main window
root = tk.Tk()
root.title("Home Page")
root.geometry("300x100")

#Add a label widget
label = tk.Label(root, text="Hello Friend \n")
label.pack()

# Add a button widget
button = tk.Button(root, text="CLick Me!", command=button_click)
button.pack()

# Styling the button widget
button.config(fg="white", bg="black")

# Start the event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox as msgbox
from PIL import Image, ImageTk

def welcomeMessage(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.titlt("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {iusername}\n")
    label_1.pack()
    label_2 = tk.Label(eindow, text="This is Pythin GUI with Tkinter")
    label_2.pack()

    #Run the Tkinter event loop
    root.mainloop()

def submit():
    username = username_entry.get()
    passwrod = password_entry.get()

    if username == "Mary" and password == "cos102":
        welcomeMessage(username)
    else:
        messagebox.showerror("Login","Invalid username or password")

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")

# Create username label and entry
username_label = tk.Label(root, text="Username:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit",command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/johnnie/anaconda3/lib/python3.13/tkinter/__init__.py", line 2074, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "/tmp/ipykernel_24125/777857180.py", line 21, in submit
#     passwrod = password_entry.get()
#                ^^^^^^^^^^^^^^
# NameError: name 'password_entry' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/johnnie/anaconda3/lib/python3.13/tkinter/__init__.py", line 2074, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "/tmp/ipykernel_24125/777857180.py", line 21, in submit
#     passwrod = password_entry.get()
#                ^^^^^^^^^^^^^^
# NameError: name 'password_entry' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/johnnie/anaconda3/lib/python3.13/tkinter/__init__.py", line 2074, in __call__
# ...
